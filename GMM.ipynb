# %%
import numpy as np
from sklearn.mixture import GaussianMixture

from toolboxes.exam_toolbox import *
# Out:
# /Users/nvalett/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from IPython.display import Image, display
display(Image(filename='figures/GMM.png', width=600))

# %%
GMM_Plot = gmm()
# We plot different options for first cluster:
mu = [[-1.5], [3.4]] # defining the mean/center of the Gaussian (mX, mY)
cov = [[1.6, 1.3], [1.3, 1.2]]   # defining the covariance matrix left-right, row by row
GMM_Plot.plot_gmm(mu,cov)

mu = [[10.1], [-7.2]] # defining the mean/center of the Gaussian (mX, mY)
cov = [[2.4, 1.6], [1.6, 3.0]]   # defining the covariance matrix left-right, row by row
GMM_Plot.plot_gmm(mu,cov)

mu = [[9.9], [-8.8]] # defining the mean/center of the Gaussian (mX, mY)
cov = [[1.6, -1.7], [-1.7, 2.9]]   # defining the covariance matrix left-right, row by row
GMM_Plot.plot_gmm(mu,cov)

# %%
GMM_Plot = gmm()
# We plot different options for first cluster:
mu = [[1.8422], [2.4306]] # defining the mean/center of the Gaussian (mX, mY)
cov = [[3.8237, 1.7104], [1.7104, 0.7672]]   # defining the covariance matrix left-right, row by row
# GMM_Plot.plot_gmm(mu,cov)

mu = [[-1.2222], [0.1830]] # defining the mean/center of the Gaussian (mX, mY)
cov = [[0.2639, 0.0803], [0.0803, 0.0615]]   # defining the covariance matrix left-right, row by row
# GMM_Plot.plot_gmm(mu,cov)

mu = [[-0.6687], [-0.7343]] # defining the mean/center of the Gaussian (mX, mY)
cov = [[0.1166, -0.0771], [-0.0771, 0.1729]]   # defining the covariance matrix left-right, row by row
GMM_Plot.plot_gmm(mu,cov)

mu = [[-0.6687], [-0.7343]] # defining the mean/center of the Gaussian (mX, mY)
cov = [[4.0475, -1.5818], [-1.5818, 1.1146]]   # defining the covariance matrix left-right, row by row
GMM_Plot.plot_gmm(mu,cov)

# %% [markdown]
# PLOT DENSITY OF 1D GMM:
# Assuming the Gaussian's are independent, and you want to plot the pdf, you can just combine the underlying Gaussian pdfs weighted by the probabilities:

# %%
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt

means = 18.347, 14.997, 18.421
stdevs = 1.2193, 0.986, 1.1354
weights = 0.13, 0.55, 0.32

x = np.arange(0., 4., 1)

pdfs = [p * ss.norm.pdf(x, mu, sd) for mu, sd, p in zip(means, stdevs, weights)]

density = np.sum(np.array(pdfs), axis=0)
plt.plot(x, density)
